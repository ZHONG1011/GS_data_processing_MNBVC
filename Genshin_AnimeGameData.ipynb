# %% [markdown]
# # Genshin语料数据
# > 来源：https://github.com/DimbreathBot/AnimeGameData/tree/master
#
# 在以上链接中，除去文件夹BinOutput和ExcelBinOutput（与多语言平行语料相关的文件夹为：Readable(txt文件)、Subtitle（srt文件）和TextMap（json文件）），其项目结构为：
# <pre>
# .
# ├─Readable
# │  ├─CHS
# │  ├─CHT
# │  ├─DE
# │  ├─EN
# │  ├─ES
# │  ├─FR
# │  ├─ID
# │  ├─IT
# │  ├─JP
# │  ├─KR
# │  ├─PT
# │  ├─RU
# │  ├─TH
# │  ├─TR
# │  └─VI
# ├─Subtitle
# │  ├─CHS
# │  ├─CHT
# │  ├─DE
# │  ├─EN
# │  ├─ES
# │  ├─FR
# │  ├─ID
# │  ├─IT
# │  ├─JP
# │  ├─KR
# │  ├─PT
# │  ├─RU
# │  ├─TH
# │  ├─TR
# │  └─VI
# └─TextMap
# </pre>

# %%
import os
import hashlib
import pandas as pd
import re
import json
import datetime

root_directory = os.getcwd()

# %% [markdown]
# # 数据抽取
# > 将语料文本提取为dataframe以便整理

# %% [markdown]
# ## txt文件处理(Readable文件夹)
# 由于这些文件中不包含id可以对齐文本，只能使用文件名或同文件名下同一行的文本作为不同语料之间的对齐

# %%
txt_directory = os.path.join(root_directory, 'Readable')
txt_folders = [x for x in os.listdir(txt_directory)]
# 数据读取
def process_folder(path, folder):
    folder_path = os.path.join(path, folder)
    all_files_data = []

    # 遍历文件夹中的所有txt文件
    for txt_file in os.listdir(folder_path):
        if txt_file.endswith(".txt"):
            file_path = os.path.join(folder_path, txt_file)
            with open(file_path, 'r', encoding='utf-8') as file:
                lines = file.readlines()
            
            for idx, line in enumerate(lines):
                cleaned_line = line.strip()

                file_name = re.sub(f'_{folder}.txt', '.txt', txt_file)
                all_files_data.append({
                    'file_name': file_name,
                    'line_number': idx + 1,
                    f'text_{folder}': cleaned_line
                })           
                  
    return all_files_data

df_CHS = pd.DataFrame(process_folder(txt_directory, 'CHS'))
df_CHS
# Out:
#                file_name  line_number  \
# 0       AmborLicense.txt            1
# 1       AmborLicense.txt            2
# 2       AmborLicense.txt            3
# 3       AmborLicense.txt            4
# 4       AmborLicense.txt            5
# ...                  ...          ...
# 23980      Wq7724401.txt            1
# 23981      Wq7724401.txt            2
# 23982      Wq7724401.txt            3
# 23983      Wq7724401.txt            4
# 23984  ZhongmofanPic.txt            1
#
#                                                 text_CHS
# 0                                      1、飞行前请确认您的身心健康状态。
# 1
# 2                                      2、起飞时请借助风场或较高的地势。
# 3
# 4                             3、使用风之翼飞行时请注意风势与风向，维持飞行平衡。
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  …按惯例，夜间在<color=#FFE14BFF>「后山枯树」</color>进行交易，至于...
# 23982  …事实上只要利用元素转化后的能量进行充能，即能恢复运作功能呢，至于转化充能所用容器，自然不必...
# 23983         …不过还望到时能携带特殊个体「奔奔」，我们的研究员对此十分感兴趣，或可作为研究参考…
# 23984                        <image name=UI_ShrinePic1/>
#
# [23985 rows x 3 columns]

# %%
df_txt_merge = df_CHS.copy()
del df_CHS
for folder in txt_folders:
    if folder != 'CHS':
        df = pd.DataFrame(process_folder(txt_directory, folder)) 
        df_txt_merge = pd.merge(df_txt_merge, df, on=['file_name', 'line_number'], how='outer')
        print(f'成功读取{folder}文件夹语料')

df_txt_merge
# Out:
# 成功读取CHT文件夹语料
# 成功读取DE文件夹语料
# 成功读取EN文件夹语料
# 成功读取ES文件夹语料
# 成功读取FR文件夹语料
# 成功读取ID文件夹语料
# 成功读取IT文件夹语料
# 成功读取JP文件夹语料
# 成功读取KR文件夹语料
# 成功读取PT文件夹语料
# 成功读取RU文件夹语料
# 成功读取TH文件夹语料
# 成功读取TR文件夹语料
# 成功读取VI文件夹语料
#                file_name  line_number  \
# 0       AmborLicense.txt            1
# 1       AmborLicense.txt            2
# 2       AmborLicense.txt            3
# 3       AmborLicense.txt            4
# 4       AmborLicense.txt            5
# ...                  ...          ...
# 23980      Wq7724401.txt            1
# 23981      Wq7724401.txt            2
# 23982      Wq7724401.txt            3
# 23983      Wq7724401.txt            4
# 23984  ZhongmofanPic.txt            1
#
#                                                 text_CHS  \
# 0                                      1、飞行前请确认您的身心健康状态。
# 1
# 2                                      2、起飞时请借助风场或较高的地势。
# 3
# 4                             3、使用风之翼飞行时请注意风势与风向，维持飞行平衡。
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  …按惯例，夜间在<color=#FFE14BFF>「后山枯树」</color>进行交易，至于...
# 23982  …事实上只要利用元素转化后的能量进行充能，即能恢复运作功能呢，至于转化充能所用容器，自然不必...
# 23983         …不过还望到时能携带特殊个体「奔奔」，我们的研究员对此十分感兴趣，或可作为研究参考…
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                 text_CHT  \
# 0                                      1、飛行前請確認您的身心健康狀態。
# 1
# 2                                      2、起飛時請借助風場或較高的地勢。
# 3
# 4                             3、使用風之翼飛行時請注意風勢與風向，維持飛行平衡。
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  …按慣例，夜間在<color=#FFE14BFF>「後山枯樹」</color>進行交易，至於...
# 23982  …事實上只要利用元素轉化後的能量進行充能，即能恢復運作功能呢，至於轉化充能所用容器，自然不必...
# 23983         …不過還望到時能攜帶特殊個體「奔奔」，我們的研究員對此十分感興趣，或可作為研究參考…
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_DE  \
# 0      1. Vergewissere dich deiner geistigen und körp...
# 1
# 2      2. Starte von einem Windfeld oder hoch gelegen...
# 3
# 4      3. Achte bei der Nutzung eines Windgleiters au...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ... Wie immer treffen wir uns am Abend unter d...
# 23982  ... Tatsächlich kann es durch Aufladen mit der...
# 23983  ... Aber es wird erwartet, dass das spezielle ...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_EN  \
# 0      1. Before gliding, make sure you are physicall...
# 1
# 2      2. Make use of a wind current or elevated terr...
# 3
# 4      3. Keep an eye on the wind conditions while gl...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ...As per usual, our exchange will be carried ...
# 23982  ...It just needs to be charged using energy ob...
# 23983  ...However, we hope you could bring along that...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_ES  \
# 0      1. Antes de volar, compruebe que está en buen ...
# 1
# 2      2. Despegue ayudándose de una corriente de vie...
# 3
# 4      3. Tenga en cuenta la velocidad y dirección de...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ... Como de costumbre, nos reuniremos por la n...
# 23982  ... En realidad, solo hay que cargarlo utiliza...
# 23983  ... Sin embargo, esperamos que pueda traer ese...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_FR  \
# 0      1. Veuillez vous assurer que vous êtes physiqu...
# 1
# 2      2. Commencez par vous entraîner avec un champ ...
# 3
# 4      3. Faites attention à la force et la direction...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ... Comme d'habitude, nous effectuerons la tra...
# 23982  ... Il suffit de le charger en utilisant de l'...
# 23983  ... Cependant, nous espérons que vous pourrez ...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_ID  \
# 0      1. Sebelum terbang, pastikan kesehatan tubuh d...
# 1
# 2      2. Manfaatkan arus angin atau ketinggian yang ...
# 3
# 4      3. Perhatikanlah kondisi angin di setiap waktu...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ... Seperti biasanya, perdagangan dilakukan pa...
# 23982  ... Sebenarnya, fungsinya dapat bekerja kembal...
# 23983  ... Tetapi kami juga berharap kamu dapat memba...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_IT  \
# 0      1. Prima di usare un aliante, preparati fisica...
# 1
# 2      2. Per il decollo sfrutta le correnti d'aria o...
# 3
# 4      3. Mentre voli tieni d'occhio le condizioni de...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ...Come al solito, la negoziazione si svolgerà...
# 23982  ...Ha solo bisogno di essere ricaricato usando...
# 23983  ...A ogni modo, speriamo ancora di riuscire ad...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_JP  \
# 0                                  1、飛行前に心身の健康状態を確認すること。
# 1
# 2                             2、飛び立つ時は風域、または高い地形を利用すること。
# 3
# 4                   3、風の翼を使用する時は風力と風向きに注意して、バランスを維持すること。
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  …いつも通り、夜に<color=#FFE14BFF>「裏山の枯れ木」</color>で取引を...
# 23982  …実のところ、元素変化を起こした後のエネルギーでチャージすれば、すぐに再起動できる。チャージ...
# 23983  …だが、その時はぜひ特殊個体「ブンブン」を連れて来てほしい。研究員たちはそれについて大変な興...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_KR  \
# 0                              1. 비행 전 심신의 건강 상태를 체크하세요.
# 1
# 2                    2. 날아오를 때는 윈드 필드를 이용하거나 높은 곳이 좋습니다.
# 3
# 4      3. 바람의 날개를 사용해 비행할 때에는 바람의 세기와 방향에 유의하여 평형을 유지...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  …관례에 따라 거래는 늦은 밤 <color=#FFE14BFF>「뒷산의 고목」</co...
# 23982  …원소 전환을 마친 에너지로 충전을 한다면 운동 기능을 바로 회복할 수 있을 겁니다...
# 23983  …거래 현장에 오실 때는 특수 개체 「붐붐」과 함께 오시기 바랍니다. 저희 쪽 연구...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_PT  \
# 0      1. Antes de planar, certifique-se de que você ...
# 1
# 2      2. Faça uso de uma corrente de vento ou de um ...
# 3
# 4      3. Fique de olho nas condições do vento enquan...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ...Como de costume, fizemos o combinado na <co...
# 23982  ...Na verdade, ele só precisa ser carregado us...
# 23983  ...Entretanto, ainda esperamos conseguir o obj...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_RU  \
# 0      1. Перед полётом убедитесь в том, что вы готов...
# 1
# 2      2. Для взлёта используйте ветряные потоки или ...
# 3
# 4      3. Следите за воздушными потоками, чтобы не по...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ...Сделка пройдёт по обычной схеме, встречаемс...
# 23982  ...Решение довольно простое: чтобы вернуть объ...
# 23983  ...Однако мы надеемся, что вы возьмёте объект ...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_TH  \
# 0      1. เตรียมตัวให้พร้อมทั้งสภาพร่างกายและจิตใจก่อ...
# 1
# 2           2. พุ่งตัวออกจากพื้นที่สูงชัน หรือกระแสลมแรง
# 3
# 4      3. ตรวจสอบกระแสลมในขณะที่ใช้เครื่องร่อนเวหาบิน...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ...โดยปกติแล้ว การค้าขายจะดำเนินที่ <color=#FF...
# 23982  ...อันที่จริง เพียงแค่ใช้พลังงานที่ได้รับจากกา...
# 23983  ...อย่างไรก็ตาม เราหวังว่าคุณจะนำวัตถุพิเศษ "B...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_TR  \
# 0      1. Uçuştan önce fiziksel ve zihinsel olarak ha...
# 1
# 2      2. Kalkış için rüzgar akımından ya da yüksek b...
# 3
# 4      3. Uçuş sırasında dengenizi koruyabilmek için ...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ... Takas her zamanki gibi <color=#FFE14BFF>da...
# 23982  ... Aslında, sadece Element Dönüşümünden elde ...
# 23983  ... Ancak yine de özel nesne olan "Benben"i de...
# 23984                        <image name=UI_ShrinePic1/>
#
#                                                  text_VI
# 0      1. Trước khi bay hãy xác nhận trạng thái thể c...
# 1
# 2      2. Khi cất cánh hãy mượn sức gió hoặc nơi có đ...
# 3
# 4      3. Khi dùng Phong Chi Dực bay lên hãy chú ý sứ...
# ...                                                  ...
# 23980                  <image name=UI_ScribbledMap_01 />
# 23981  ...Theo thường lệ, tiến hành giao dịch tại <co...
# 23982  ...Trên thực tế chỉ cần tận dụng năng lượng sa...
# 23983  ...Nhưng vẫn mong đến lúc đó có thể đem theo c...
# 23984                        <image name=UI_ShrinePic1/>
#
# [23985 rows x 17 columns]

# %%
# len(df_txt_merge[df_txt_merge['zh_text_md5'].isna()])

# %% [markdown]
# ## srt文件处理(Subtitle文件夹)
# 以下为srt字幕数据的结构：
# <pre>
# 1
# 00:00:02,603 --> 00:00:07,228
# 在世上的第一缕风刚开始吹拂时
#
# 2
# 00:00:07,228 --> 00:00:10,928
# 向往高空的鸟雀拥有翅膀
#
# 3
# 00:00:10,928 --> 00:00:13,128
# 却无法飞翔
# ...
# </pre>
#
# 可知其文件内容结构为：
# - 文本内容序号（一般字幕数据没有这行）
# - 字幕时间，会因为语言版本不同而不同
# - 文本内容
#
# 存在问题：
# >- 有109个文件存在文本内容不对齐的情况。在原文件排查原因，可能是不同语言版本单独配了不同的音频导致内容不同，例如日语版本的文件与中文的有出入。
# >- 不同语言在句式上的不同(如句子成分顺序不同)导致匹配错位等情况
# >
# 虽然想过通过srt的字幕时间进行不同语种间的对齐，但没达到理想效果，因此选择**将同一文件下的所有文本内容提取，使用换行符进行间隔，通过文件名进行语料对齐。**

# %%
# 提取示例1
srt_file = r".\Subtitle\CHS\Cs_GY11030_GYPersonal_CHS.srt"
with open(srt_file, 'r', encoding='utf-8') as file:
    lines = file.readlines()

i = 0
j = 2
line_num = 0
for line in lines:
    if line_num == i:
        print(line)
        i = i + 4
    if line_num == j:
        print(line)
        j = j + 4

    line_num = line_num + 1
# Out:
# 1
#
# 麒麟是众仙中的仁兽
#
# 2
#
# 饮必甘露，食必嘉禾
#
# 3
#
# 但或许，绝云间的仙山与洞府…
#
# 4
#
# 对她「人类」的一面来说
#
# 5
#
# 有些太过寂寞
#
# 6
#
# 昨夜月光之下
#
# 7
#
# 我望见甘雨独自站在崖边
#
# 8
#
# 眺望山间岚气
#
# 9
#
# 苍茫云海
#
# 10
#
# 将她单薄的身影淹没
#
# 11
#
# 我看到了她的孤独
#
# 12
#
# 所以想要上前劝她回归凡尘…
#
# 13
#
# 但也正是在那时
#
# 14
#
# 我听见了那几句话
#
# 15
#
# 「璃月港的孤独」
#
# 16
#
# 「比绝云间更加孤独」
#
# 17
#
# 「在绝云间看云」
#
# 18
#
# 「只不过是一个人看云的孤独」
#
# 19
#
# 「走入璃月的人海」
#
# 20
#
# 「却是『非人之物』」
#
# 21
#
# 「在世间的孤独」

# %%
# 示例2,对比以上简中文件，在内容上行数并未对齐，例如这里的第七句对应上面的第十一句
srt_file = r".\Subtitle\FR\Cs_GY11030_GYPersonal_FR.srt"
def parse_srt(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    
    blocks = re.findall(r'(\d+)\n(\d{2}:\d{2}:\d{2},\d{3}) --> (\d{2}:\d{2}:\d{2},\d{3})\n(.*?)\n\n', content, re.DOTALL)
    parsed = []
    for block in blocks:
        seq, start_time, end_time, text = block
        parsed.append({
            'seq': int(seq),
            'start_time': start_time,
            'end_time': end_time,
            'text': text.replace('\n', '')
        })
    return parsed

pd.DataFrame(parse_srt(srt_file))
# Out:
#     seq    start_time      end_time  \
# 0     1  00:00:00,600  00:00:04,300
# 1     2  00:00:04,575  00:00:09,152
# 2     3  00:00:09,817  00:00:14,000
# 3     4  00:00:14,725  00:00:17,648
# 4     5  00:00:17,825  00:00:21,175
# 5     6  00:00:21,175  00:00:26,825
# 6     7  00:00:27,208  00:00:31,375
# 7     8  00:00:32,025  00:00:34,055
# 8     9  00:00:34,055  00:00:37,750
# 9    10  00:00:38,375  00:00:43,325
# 10   11  00:00:44,325  00:00:48,825
# 11   12  00:00:48,825  00:00:52,125
# 12   13  00:00:52,375  00:00:56,075
# 13   14  00:00:56,400  00:00:58,925
# 14   15  00:00:59,250  00:01:04,000
#
#                                                  text
# 0   Les Qilin sont les plus bienveillants parmi to...
# 1   Ils ne boivent que de l'eau de source et ne ma...
# 2   Mais peut-être que les habitations montagneuse...
# 3   Sa moitié humaine lui fait ressentir quelque s...
# 4                  À la lumière de la lune hier soir,
# 5   j'ai vu Ganyu se tenir sur la falaise contempl...
# 6   Son visage fin tout entier absorbé par le vast...
# 7                              J'ai senti sa solitude
# 8   et ai essayé de la convaincre de revenir dans ...
# 9   Mais c'est alors qu'elle a prononcé les mots s...
# 10  « Je me sens encore plus seule à Liyue qu'au K...
# 11  « Quand je contemple les nuages depuis le Kars...
# 12  je ressens juste la solitude de celui qui rega...
# 13  « Mais perdue au milieu de la marée humaine de...
# 14  la solitude qui m'habite est celle d'un être n...

# %%
srt_directory = os.path.join(root_directory, 'Subtitle')
srt_folders = [x for x in os.listdir(srt_directory)]

def extract_text_from_srt(srt_file):
    with open(srt_file, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    i = 3
    line_num = 0
    extracted_lines = ''
    for line in lines:
        line_num += 1
        if line_num == i:
            extracted_lines += line
            i += 4

    return extracted_lines

def process_folder(path, folder):
    folder_path = os.path.join(path, folder)
    all_files_data = []

    # 遍历文件夹中的所有txt文件
    for srt_file in os.listdir(folder_path):
        if srt_file.endswith(".srt"):
            file_path = os.path.join(folder_path, srt_file)
            file_text = extract_text_from_srt(file_path)

            file_name = re.sub(f'_{folder}.srt', '.srt', srt_file)

            all_files_data.append({
                'file_name': file_name,
                f'text_{folder}': file_text
            })
                  
    return all_files_data

df_srt_merge = pd.DataFrame(process_folder(srt_directory, 'CHS'))

for folder in srt_folders:
    if folder != 'CHS':
        df = pd.DataFrame(process_folder(srt_directory, folder)) 
        df_srt_merge = pd.merge(df_srt_merge, df, on=['file_name'], how='outer')
        print(f'成功读取{folder}文件夹语料')

df_srt_merge['line_number'] = 1
# Out:
# 成功读取CHT文件夹语料
# 成功读取DE文件夹语料
# 成功读取EN文件夹语料
# 成功读取ES文件夹语料
# 成功读取FR文件夹语料
# 成功读取ID文件夹语料
# 成功读取IT文件夹语料
# 成功读取JP文件夹语料
# 成功读取KR文件夹语料
# 成功读取PT文件夹语料
# 成功读取RU文件夹语料
# 成功读取TH文件夹语料
# 成功读取TR文件夹语料
# 成功读取VI文件夹语料

# %%
df_srt_merge
# Out:
#                           file_name  \
# 0                Ambor_Readings.srt
# 1                    battlePass.srt
# 2          Cs_102106_Summon_Boy.srt
# 3         Cs_102106_Summon_Girl.srt
# 4    Cs_102203_BeforeBattle_Boy.srt
# ..                              ...
# 187                     MDAQ041.srt
# 188     MDAQ063_ZhaiXingYaSideB.srt
# 189         OpeningSequence_Boy.srt
# 190        OpeningSequence_Girl.srt
# 191                       Title.srt
#
#                                               text_CHS  \
# 0    在世上的第一缕风刚开始吹拂时\n向往高空的鸟雀拥有翅膀\n却无法飞翔\n他们询问风神\n自己...
# 1    曾经，天上有一个荣光的王国。\n那国王派遣第一位王储去黑暗之国寻找创世的珍珠。\n于是第一位...
# 2    拭目以待吧，失去神明的国度\n会不会被远古的恶意重新吞没？\n不过，如果你们也想陪璃月人一起...
# 3    拭目以待吧，失去神明的国度\n会不会被远古的恶意重新吞没？\n不过，如果你们也想陪璃月人一起...
# 4                               是「愚人众」！\n他们朝「归终机」来了！\n
# ..                                                 ...
# 187  我要说的故事开始于太古\n那时众神还行走于大地\n天空之龙自天空降下\n对世间的一切都充满好...
# 188          殿下…您的仆人又为您带回了一场胜利\n当您的国度重临尘世\n我们将分享它的荣光\n
# 189  你从极寒中复苏，希望与这世界相处愉快\n然而当你睁眼，却见到妹妹正被锁链刺穿——\n陌生的神...
# 190  你从极寒中复苏，希望与这世界相处愉快\n然而当你睁眼，却见到哥哥正被锁链刺穿——\n陌生的神...
# 191                                                NaN
#
#                                               text_CHT  \
# 0    在世上的第一縷風剛開始吹拂時\n嚮往高空的鳥雀擁有翅膀\n卻無法飛翔\n他們詢問風神\n自己...
# 1    曾經，天上有一個榮光的王國\n那國王派遣第一位王儲去黑暗之國尋找創世的珍珠\n於是第一位王儲...
# 2    拭目以待吧，失去神明的國度\n會不會被遠古的惡意重新吞沒？\n不過，如果你們也想陪璃月人一起...
# 3    拭目以待吧，失去神明的國度\n會不會被遠古的惡意重新吞沒？\n不過，如果你們也想陪璃月人一起...
# 4                               是「愚人眾」！\n他們朝「歸終機」來了！\n
# ..                                                 ...
# 187  我要說的故事開始於太古\n那時眾神還行走於大地\n天空之龍自天空降下\n對世間的一切都充滿好...
# 188          殿下…您的僕人又為您帶回了一場勝利\n當您的國度重臨塵世\n我們將分享它的榮光\n
# 189  你從極寒中復甦，希望與這世界相處愉快\n然而當你睜眼，卻見到妹妹正被鎖鏈刺穿——\n陌生的神...
# 190  妳從極寒中復甦，希望與這世界相處愉快\n然而當妳睜眼，卻見到哥哥正被鎖鏈刺穿——\n陌生的神...
# 191            世界崩壞之後\n兩顆隕星落在世界中央\n降臨大地的雙子\n正有一人將要醒來\n
#
#                                                text_DE  \
# 0    Als der erste Wind dieser Welt über das Land z...
# 1    Es war einmal ein glanzvolles Königreich, dess...
# 2    Mal sehen, ob die Stadt, die ihre Gottheit ver...
# 3    Mal sehen, ob die Stadt, die ihre Gottheit ver...
# 4    Die Fatui!\nSie greifen das Guizhong-Geschütz ...
# ..                                                 ...
# 187  Diese Geschichte handelt in grauer Vorzeit,\na...
# 188  Eure Hoheit ... Euer getreuer Diener hat erneu...
# 189  Du erwachst aus der Kälte und trägst große Hof...
# 190  Du erwachst aus der Kälte und trägst große Hof...
# 191  Nachdem die Welt zusammengebrochen war,\nfiele...
#
#                                                text_EN  \
# 0    When the first wisp of wind brushed across the...
# 1    Once, there was a glorious kingdom established...
# 2    Hahahahaha! Let's see — will the nation that h...
# 3    Hahahahaha! Let's see — will the nation that h...
# 4    The Fatui!\nThey're attacking the Guizhong Bal...
# ..                                                 ...
# 187  What is to be sung transpired in days of yore\...
# 188  Your Highness... Your humble servant returns\n...
# 189  You opened your eyes in the bitter cold with t...
# 190  You opened your eyes in the bitter cold with t...
# 191  Two stars clashed\nWith the heart of a shatter...
#
#                                                text_ES  \
# 0    Cuando la primera brizna de viento rozó la tie...
# 1    Érase una vez un glorioso reino en los cielos....
# 2    Veamos, ¿creen que la nación que perdió a su d...
# 3    Veamos, ¿creen que la nación que perdió a su d...
# 4    ¡Son los Fatui!\n¡Están atacando la Balista Gu...
# ..                                                 ...
# 187  La historia que les contaré comenzó en los día...
# 188  Su Alteza... Su humilde sirviente regresó.\nCu...
# 189  Renaces en medio del gélido frío con la espera...
# 190  Renaces en medio del gélido frío con la espera...
# 191  Después de que la tierra colapsó\nDos meteorit...
#
#                                                text_FR  \
# 0    Lorsque la première brise effleura la terre,\n...
# 1    Autrefois existait dans les cieux un royaume g...
# 2    Attendons et voyons. Le pays qui a perdu son d...
# 3    Attendons et voyons. Le pays qui a perdu son d...
# 4    Les Fatui !\nIls se dirigent vers la baliste d...
# ..                                                 ...
# 187  L'histoire qui va vous être contée remonte à d...
# 188  Votre Altesse, votre humble serviteur vous app...
# 189  Vos yeux s'ouvrent dans l'espoir de voir un mo...
# 190  Vos yeux s'ouvrent dans l'espoir de voir un mo...
# 191  Le déclin du monde\ndonna naissance à deux éto...
#
#                                                text_ID  \
# 0    Saat angin pertama kali berhembus di dunia\nBu...
# 1    Pada zaman dahulu, terdapat sebuah kerajaan ya...
# 2    Hahahahaha, kita lihat saja, akankah negara ya...
# 3    Hahahahaha, kita lihat saja, akankah negara ya...
# 4    Ada orang-orang Fatui!\nMereka menyerang Guizh...
# ..                                                 ...
# 187  Kisah ini dimulai dari zaman dahulu kala\nSaat...
# 188  Tuanku... hamba-hambamu lagi-lagi kembali memb...
# 189  Kamu terbangun dalam kedinginan, berharap untu...
# 190  Kamu terbangun dalam kedinginan, berharap untu...
# 191  Sepasang meteor terjatuh\nDengan hati dari dun...
#
#                                                text_IT  \
# 0    Quando il primo soffio di vento sfiorò la terr...
# 1    Un tempo, tra i cieli vi era un regno florido....
# 2    Ahahahahah!\nChissà se la nazione che ha perso...
# 3    Ahahahahah! \nChissà se la nazione che ha pers...
# 4    I Fatui!\nStanno attaccando la balista Guizhon...
# ..                                                 ...
# 187  La storia che sto per narrare è accaduta in gi...
# 188  Maestà... Il suo umile servo ha fatto ritorno....
# 189  Sperando in un mondo migliore, apri gli occhi ...
# 190  Sperando in un mondo migliore, apri gli occhi ...
# 191  Due stelle si scontrarono\ncol cuore di un mon...
#
#                                                text_JP  \
# 0    世界に最初の風が吹いた時\n空に羨望を抱いたスズメは翼があるにもかかわらず\n飛ぶことができ...
# 1    かつて 天空には栄光の王国があった\n国王は 王位継承者第一位に暗黒の国へと行き 創世の真珠...
# 2    神を失った国は 上古の悪意に再び呑み込まれるのか\n楽しみだ\nもちろん 璃月の人と一緒に溺...
# 3    神を失った国は 上古の悪意に再び呑み込まれるのか\n楽しみだ\nもちろん 璃月の人と一緒に溺...
# 4                            ファデュイだ！\n「帰終機」に向かって来たぞ！\n
# ..                                                 ...
# 187  ボクが話すは 古の始まり\n神々がまだ 大地を歩く時代の物語\n天空の龍が 空から降り立ち\...
# 188  殿下 貴方様のしもべはまた勝利を勝ち取りました \n貴方様の国がこの世に再び降臨する時\n我...
# 189  極寒から蘇った君は、この世界との懇意を願っていた\nしかし、目を開けた先に映ったのは、鎖に貫...
# 190  極寒から蘇った君は、この世界との懇意を願っていた\nしかし、目を開けた先に映ったのは、鎖に貫...
# 191  世界崩壊の後\n二つの隕星が世界の中心へと落ちた\n大地に降臨した双子\nその片方に目覚めの...
#
#                                                text_KR  \
# 0    세상에 최초의 바람이 불기 시작할 때\n하늘을 동경하던 새들은 날개가 있었지만\n날...
# 1    한때, 하늘엔 영광의 왕국이 있었어\n그 나라의 왕은 첫째 왕녀를 보내 어둠의 나라...
# 2    지켜봐. 과연 신을 잃은 나라는\n또다시 고대 악에 의해 삼켜질까?\n그래도 너희가...
# 3    지켜봐. 과연 신을 잃은 나라는\n또다시 고대 악에 의해 삼켜질까?\n그래도 너희가...
# 4                         「우인단」이야!\n「귀종기」 쪽으로 오고 있어!\n
# ..                                                 ...
# 187  이건 아주 오래전 태고 시절부터 시작된 이야기야\n신들이 아직 살아 숨 쉬고 있을 ...
# 188  전하...전하의 종복이 또다시 승리를 쟁취해왔나이다\n전하의 나라가 다시 세상에 모...
# 189  혹한 속에서 깨어난 당신은 이 세계와 화목하게 지내길 바랐지만\n\n하늘에서 내려온...
# 190  혹한 속에서 깨어난 당신은 이 세계와 화목하게 지내길 바랐지만\n눈에 들어온 건 차...
# 191                      \n두 개의 운석이 세계의 중심에 떨어졌다\n\n\n
#
#                                                text_PT  \
# 0    Quando a primeira brisa do mundo começou a sop...
# 1    Antes, havia um reino glorioso estabelecido en...
# 2    Vejamos - será que a nação que perdeu sua divi...
# 3    Vejamos - será que a nação que perdeu sua divi...
# 4    Os Fatuis!\nEles estão atacando a Balista Guiz...
# ..                                                 ...
# 187  A história que vou contar começou desde os pri...
# 188  Vossa Alteza... seu humilde servente voltou de...
# 189  Você abre seus olhos no frio com a esperança d...
# 190  Você abre seus olhos no frio com a esperança d...
# 191  Após o colapso do mundo\nDois meteoritos caíra...
#
#                                                text_RU  \
# 0    Когда первый ветер пронёсся по земле,\nУ птиц,...
# 1    Однажды среди небес было славное королевство.\...
# 2    Посмотрим, не погрузится ли в смуту нация\nПот...
# 3    Посмотрим, не погрузится ли в смуту нация\nПот...
# 4            Это Фатуи!\nОни хотят сломать баллисту!\n
# ..                                                 ...
# 187  То, что должно быть спето, произошло в дни был...
# 188  Ваше высочество... Ваш покорный слуга возвраща...
# 189  Вы просыпаетесь от сильного холода и с надеждо...
# 190  Вы просыпаетесь от сильного холода и с надеждо...
# 191  После конца света\nС небес на землю упали два ...
#
#                                                text_TH  \
# 0    เมื่อลมกระแสแรกพัดผ่านดินแดน\nเหล่านกที่มีปีกต...
# 1    ครั้งหนึ่ง มีอาณาจักรอันแสนรุ่งโรจน์อยู่บนท้อง...
# 2    คอยดูละกัน ว่าอาณาจักรที่สูญเสียเทพเจ้าไปน่ะ\n...
# 3    คอยดูละกัน ว่าอาณาจักรที่สูญเสียเทพเจ้าไปน่ะ\n...
# 4    พวก Fatui นี่นา!\nพวกมันบุกมาโจมตี Guizhong Ba...
# ..                                                 ...
# 187  เรื่องราวที่จะเล่านี้เกิดขึ้นในโบราณกาล\nครั้ง...
# 188  นายท่าน...ข้ารับใช้ผู้ซื่อสัตย์ของท่านกลับมาพร...
# 189  คุณลืมตาตื่นขึ้นในสถานที่อันแสนหนาวเหน็บ พร้อม...
# 190  คุณลืมตาตื่นขึ้นในสถานที่อันแสนหนาวเหน็บ พร้อม...
# 191  หลังจากโลกล่มสลาย\nอุกกาบาตสองลูกได้ตกลงมายังพ...
#
#                                                text_TR  \
# 0    Rüzgarın ilk esintisi vurduğunda tüm diyara\ng...
# 1    Bir zamanlar gökyüzünde görkemli bir krallık v...
# 2    Hahaha! Bakalım ilahını kaybeden bir ulus\nbir...
# 3    Hahaha! Bakalım ilahını kaybeden bir ulus\nbir...
# 4        Fatui!\nGuizhong Balistasına saldırıyorlar!\n
# ..                                                 ...
# 187  Anlatacaklarım çok eski zamanlara dayanır...\n...
# 188  Majesteleri... Mütevazı hizmetkarınız geri dön...
# 189  Dondurucu soğuk içine işlerken daha iyi bir dü...
# 190  Dondurucu soğuk içine işlerken daha iyi bir dü...
# 191  İki yıldız çarpıştı...\n...mahvolmuş dünyanın ...
#
#                                                text_VI  line_number
# 0    Khi ngọn gió đầu tiên bắt đầu thổi qua thế giớ...            1
# 1    Đã từng có một vương quốc rộng lớn trên bầu tr...            1
# 2    Hãy cùng chờ xem, liệu vương quốc mất đi thần ...            1
# 3    Hãy cùng chờ xem, liệu vương quốc mất đi thần ...            1
# 4    Là Fatui!\nChúng đang hướng về phía máy Guizho...            1
# ..                                                 ...          ...
# 187  Câu chuyện tôi muốn kể bắt đầu từ ngày xa xưa\...            1
# 188  Điện hạ... kẻ bề tôi của ngài lại đem thêm một...            1
# 189  Bạn tỉnh lại trong cực hàn, hy vọng sẽ được số...            1
# 190  Bạn tỉnh lại trong cực hàn, hy vọng sẽ được số...            1
# 191  Sau khi thế giới băng hoại\nHai viên vẫn tinh ...            1
#
# [192 rows x 17 columns]

# %%
# df_srt_merge[df_srt_merge['zh_text_md5'].isna()]

# %% [markdown]
# ## json文件处理(TextMap文件夹)
# 文件数据示例：
# <pre>
# {
#   "1014324224": "演奏开始后，俱利鼓每闪烁一次视为一个节拍。按照鼓谱，在对应的节拍击出相应的鼓声，便可以完成演奏！",
#   "1037323264": "遍布繁茂植被的郊野景致，荟萃了枫丹寻常可见的多种花卉与灌木。花与草木是绘画中寻常可见的主题，以及对于「色彩」探索的起点之一。枫丹的部分画家认为，世界的调色盘以众多植株向他们示范了「完美搭配」的典例，因此，若是一幅画中的所有色彩都能在植物身上找到原型，那这幅画必然有着自然风光般的和谐美感。当然，前提是千万别将多种植物的色彩混为一谈…",
#   "1037903872": "艾琳",
# ...
# }
# </pre>
# 由于json数据中包含id号，可以直接使用id进行合并，而不需要和处理txt或srt文件那般根据文件名和语句所在行数进行对齐。
#
# > 因为json文件中有TextMapTH_1.json和TextMapTH_2.json，因此写了针对泰语的抽取（其实也可以直接记事本打开复制粘贴统一成一个文件）。

# %%
json_directory = os.path.join(root_directory, 'TextMap')
language = ['CHS', 'CHT', 'DE', 'EN', 'ES', 'FR', 'ID', 'IT', 'JP', 'KR', 'PT', 'RU', 'TH', 'TR', 'VI']
json_files = [x for x in os.listdir(json_directory)]

def language_check(filename):
    for lang in language:
        if lang in filename:
            return lang
    return None

# 初始化
# df_json_merge = pd.DataFrame()
merged_df = pd.DataFrame()

# 专门处理 TH 数据
th_dfs = []

for file in json_files:
    print(f'正在处理 {file} 文件夹语料')
    lang = language_check(file)
    file_path = os.path.join(json_directory, file)

    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # 构造 DataFrame
    df = pd.DataFrame(list(data.items()), columns=['id', f'text_{lang}'])

    if lang == 'TH':  # 对 TH 特殊处理
        th_dfs.append(df)
        continue

    # 合并到总的 DataFrame
    if merged_df.empty:
        merged_df = df
    else:
        merged_df = pd.merge(merged_df, df, on='id', how='outer')

# 合并 TH 的两个文件
if th_dfs:
    combined_th_df = pd.concat(th_dfs, ignore_index=True).drop_duplicates(subset='id', keep='first')
    combined_th_df = combined_th_df.rename(columns={f'text_TH': 'text_TH'})  # 标准化列名
    # 合并到总的 DataFrame
    merged_df = pd.merge(merged_df, combined_th_df, on='id', how='outer')

# json文件名列，以中文语料的 json 文件为准，其余语料对齐
merged_df['file_name'] = 'TextMapCHS.json'

# 新增行号列
merged_df['line_number'] = merged_df.index + 1
# Out:
# 正在处理 TextMapCHS.json 文件夹语料
# 正在处理 TextMapCHT.json 文件夹语料
# 正在处理 TextMapDE.json 文件夹语料
# 正在处理 TextMapEN.json 文件夹语料
# 正在处理 TextMapES.json 文件夹语料
# 正在处理 TextMapFR.json 文件夹语料
# 正在处理 TextMapID.json 文件夹语料
# 正在处理 TextMapIT.json 文件夹语料
# 正在处理 TextMapJP.json 文件夹语料
# 正在处理 TextMapKR.json 文件夹语料
# 正在处理 TextMapPT.json 文件夹语料
# 正在处理 TextMapRU.json 文件夹语料
# 正在处理 TextMapTH_1.json 文件夹语料
# 正在处理 TextMapTH_2.json 文件夹语料
# 正在处理 TextMapTR.json 文件夹语料
# 正在处理 TextMapVI.json 文件夹语料

# %%
merged_df
# Out:
#                 id                                           text_CHS  \
# 0       1014324224   演奏开始后，俱利鼓每闪烁一次视为一个节拍。按照鼓谱，在对应的节拍击出相应的鼓声，便可以完成演奏！
# 1       1037323264  遍布繁茂植被的郊野景致，荟萃了枫丹寻常可见的多种花卉与灌木。花与草木是绘画中寻常可见的主题，...
# 2       1037903872                                                 艾琳
# 3       1061516288                                         少女薇拉的忧郁·卷二
# 4       1083215872                                                 派蒙
# ...            ...                                                ...
# 567870  1352415965                                                NaN
# 567871  1994081075                                                NaN
# 567872  2871507766                                                NaN
# 567873  2865597243                                                NaN
# 567874  3761771325                                                NaN
#
#                                                  text_CHT  \
# 0        演奏開始後，俱利鼓每閃爍一次視為一個節拍。按照鼓譜，在對應的節拍擊出相應的鼓聲，便可以完成演奏！
# 1       遍布繁茂植被的郊野景致，薈萃了楓丹尋常可見的多種花卉與灌木。花與草木是繪畫中尋常可見的主題，...
# 2                                                      艾琳
# 3                                              少女薇拉的憂鬱·卷二
# 4                                                      派蒙
# ...                                                   ...
# 567870                     遠古寶玉造的，能守護一國的勁弓，以匯聚一線的翠光為幻造的弦。
# 567871                                               懸黎千鈞
# 567872                                  goto -39 229 9988
# 567873                                              驟起的魔花
# 567874  傳說中，追隨風之神的詩人踏遍了一千世界。歌集中記載了諸多奇景，飽含偉力。這些斷章有些丟失了，...
#
#                                                   text_DE  \
# 0       Sobald du anfängst zu spielen, gilt jedes Blin...
# 1       Eine Landschaft mit üppiger Vegetation und ein...
# 2                                                   Ellin
# 3                                Veras Trübsinn – Band II
# 4                                                  Paimon
# ...                                                   ...
# 567870  Ein aus uralter Jade gefertigter Bogen zum Sch...
# 567871                             Urzeitlicher Jadebogen
# 567872                                  goto -39 229 9988
# 567873                          Aufstieg der Teufelsblume
# 567874  Der Legende zufolge besuchte der Dichter, der ...
#
#                                                   text_EN  \
# 0       After your performance begins, each glimmer of...
# 1       A countryside scene full of luxurious plants. ...
# 2                                                   Ellin
# 3                                  Vera's Melancholy (II)
# 4                                                  Paimon
# ...                                                   ...
# 567870  A strong bow that was made from ancient jade, ...
# 567871                              Primordial Jade Vista
# 567872                                  goto -39 229 9988
# 567873                            Rise of the Fell Flower
# 567874  Legend has it that the bard who walked with th...
#
#                                                   text_ES  \
# 0       Cuando la actuación haya comenzado, cada deste...
# 1       Un bucólico paisaje de vegetación exuberante q...
# 2                                                   Ellin
# 3                              La melancolía de Vera (II)
# 4                                                  Paimon
# ...                                                   ...
# 567870  Un gran arco hecho de un ámbar antiguo complet...
# 567871                           Vista de Jade Primordial
# 567872                                  goto -39 229 9988
# 567873                      El ascenso de la flor maldita
# 567874  La leyenda dice que el bardo que caminó con el...
#
#                                                   text_FR  \
# 0       Après le début de votre performance, chaque sc...
# 1       Une scène de campagne envahie par des plantes ...
# 2                                                  Eileen
# 3                         La Mélancolie de Véra - Tome II
# 4                                                  Paimon
# ...                                                   ...
# 567870  Un arc puissant fait de jade antique qui peut ...
# 567871                             Vue de jade primordial
# 567872                                  goto -39 229 9988
# 567873                      L'ascension de la Gangrefleur
# 567874  La légende dit qu'un barde avait parcouru des ...
#
#                                                   text_ID  \
# 0       Setelah pertunjukan dimulai, setiap kilauan Dr...
# 1       Pemandangan alam liar yang dipenuhi dengan tum...
# 2                                                   Ellin
# 3                                Kemelankolisan Vera (II)
# 4                                                  Paimon
# ...                                                   ...
# 567870  Sebuah busur kuat yang tubuhnya terbuat dari g...
# 567871                              Primordial Jade Vista
# 567872                                  goto -39 229 9988
# 567873                        Bangkitnya Bunga yang Jatuh
# 567874  Menurut legenda, penyair yang berjalan bersama...
#
#                                                   text_IT  \
# 0       Dopo l'inizio della tua esibizione, ogni bagli...
# 1       Un panorama rurale ricco di piante rigogliose....
# 2                                                   Ellin
# 3                                 Malinconia di Vera (II)
# 4                                                  Paimon
# ...                                                   ...
# 567870                                                NaN
# 567871                                                NaN
# 567872                                  goto -39 229 9988
# 567873                            L'ascesa del Demonfiore
# 567874                                                NaN
#
#                                                   text_JP  \
# 0       演奏開始後、コリュの太鼓が1回点滅するごとに1つの拍となります。楽譜に従って、正しいリズムと...
# 1       一面に草木が広がる郊外の野には、フォンテーヌでよく目にする様々な草花や低木が一堂に会している...
# 2                                                     エリン
# 3                                             少女ヴィーラの憂鬱·2
# 4                                                    パイモン
# ...                                                   ...
# 567870                上古の宝玉で作られた、一国を守れる弓。一線に集まる光は幻造の弦になる。
# 567871                                             高価なオーブ
# 567872                                  goto -39 229 9988
# 567873                                             蔓延る魔の花
# 567874  伝説では、風の神を追随する詩人が千の世界を踏破したらしい。その歌集には様々な奇景が記載されて...
#
#                                                   text_KR  \
# 0       연주에서 코리 북이 한 번 빛나는 것을 한 박자로 간주합니다. 악보에 맞춰 알맞은 ...
# 1       무성한 식물이 자라있는 야외 풍경. 폰타인에서 자주 볼 수 있는 꽃과 관목이 모여 ...
# 2                                                      엘린
# 3                                            소녀 베라의 우울·2권
# 4                                                     페이몬
# ...                                                   ...
# 567870  고대 보옥으로 만들어진 일국을 수호할 수 있는 강한 활. 푸른빛 줄기가 모여 활시위...
# 567871                                               현려천균
# 567872                                  goto -39 229 9988
# 567873                                          악마의 꽃의 습격
# 567874  전설에 의하면 바람의 신을 추종하던 시인이 전 세계를 모두 둘러보며 만들었다던 시가...
#
#                                                   text_PT  \
# 0       Após sua performance iniciar, cada brilho de u...
# 1       Uma cena rural repleta de plantas exuberantes....
# 2                                                   Ellin
# 3                                 Melancolia de Vera (II)
# 4                                                  Paimon
# ...                                                   ...
# 567870  Um arco forte feito de jade antigo, com uma co...
# 567871                           Vista da Jade Primordial
# 567872                                  goto -39 229 9988
# 567873                           Ascensão da Flor Maldita
# 567874  Diz a lenda que o bardo que andou com o Deus d...
#
#                                                   text_RU  \
# 0       Когда начнётся выступление, каждая вспышка кор...
# 1       Сельская местность с пышной растительностью. З...
# 2                                                   Айлин
# 3                                 Меланхолия Веры. Том II
# 4                                                  Паймон
# ...                                                   ...
# 567870  Лук, сделанный из древнего нефрита, с тетивой,...
# 567871                           Древняя Нефритовая Виста
# 567872                                  goto -39 229 9988
# 567873                                 Восстание Злоцвета
# 567874  Легенды гласят, что бард, который ходил с архо...
#
#                                                   text_TR  \
# 0       Müzik performansın başladığında bir Kori Davul...
# 1       Gösterişli bitkilerle dolu bir kır manzarası. ...
# 2                                                   Ellin
# 3                               Vera'nın Melankolisi (II)
# 4                                                  Paimon
# ...                                                   ...
# 567870                                                NaN
# 567871                                                NaN
# 567872                                  goto -39 229 9988
# 567873                            Düşen Çiçeğin Yükselişi
# 567874                                                NaN
#
#                                                   text_VI  \
# 0       Sau khi bắt đầu diễn tấu, mỗi khi Trống Kory n...
# 1       Khung cảnh ngoại ô với thảm thực vật tươi tốt,...
# 2                                                   Ellin
# 3                                      Vera Sầu Muộn (II)
# 4                                                  Paimon
# ...                                                   ...
# 567870  Tạo ra từ bảo ngọc viễn cổ, có thể bảo vệ một ...
# 567871                                      Cung Huyền Lê
# 567872                                  goto -39 229 9988
# 567873                                      Hoa Quỷ Nở Rộ
# 567874  Trong truyền thuyết, nhà thơ đi theo Phong Thầ...
#
#                                                   text_TH        file_name  \
# 0       หลังจากที่การแสดงเริ่มขึ้น ประกายแสงของกลอง Ko...  TextMapCHS.json
# 1       พื้นที่ชนบทที่ปกคลุมไปด้วยพืชพรรณเขียวชอุ่ม มี...  TextMapCHS.json
# 2                                                   Ellin  TextMapCHS.json
# 3                               ความเศร้าโศกของ Vera (II)  TextMapCHS.json
# 4                                                  Paimon  TextMapCHS.json
# ...                                                   ...              ...
# 567870  คันธนูที่แข็งแกร่งที่ทำจากหยกโบราณด้วยสายที่ทำ...  TextMapCHS.json
# 567871                              Primordial Jade Vista  TextMapCHS.json
# 567872                                  goto -39 229 9988  TextMapCHS.json
# 567873                            การลุกฮือของดอกไม้ปีศาจ  TextMapCHS.json
# 567874  ในตำนานเล่าว่านักกวีที่ติดตามเทพแห่งลม เดินทาง...  TextMapCHS.json
#
#         line_number
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5
# ...             ...
# 567870       567871
# 567871       567872
# 567872       567873
# 567873       567874
# 567874       567875
#
# [567875 rows x 18 columns]

# %%
# len(merged_df[merged_df.zh_text_md5.isna()])

# %% [markdown]
# # 数据合并

# %%
merged_df = merged_df.drop(columns=['id'])

# 确保列顺序相同
columns_order = ['file_name', 'line_number', 'text_CHS', 'text_CHT', 'text_DE',
                  'text_EN', 'text_ES', 'text_FR', 'text_ID', 'text_IT', 'text_JP',
                  'text_KR', 'text_PT', 'text_RU', 'text_TH', 'text_TR', 'text_VI']

merged_df = merged_df[columns_order]
df_srt_merge = df_srt_merge[columns_order]
df_txt_merge = df_txt_merge[columns_order]

# 合并所读取的txt,srt,json文件的数据框
merged_all_df = pd.concat([df_txt_merge, df_srt_merge, merged_df], axis=0, ignore_index=True)
merged_all_df
# Out:
#                file_name  line_number                    text_CHS  \
# 0       AmborLicense.txt            1           1、飞行前请确认您的身心健康状态。
# 1       AmborLicense.txt            2
# 2       AmborLicense.txt            3           2、起飞时请借助风场或较高的地势。
# 3       AmborLicense.txt            4
# 4       AmborLicense.txt            5  3、使用风之翼飞行时请注意风势与风向，维持飞行平衡。
# ...                  ...          ...                         ...
# 592047   TextMapCHS.json       567871                         NaN
# 592048   TextMapCHS.json       567872                         NaN
# 592049   TextMapCHS.json       567873                         NaN
# 592050   TextMapCHS.json       567874                         NaN
# 592051   TextMapCHS.json       567875                         NaN
#
#                                                  text_CHT  \
# 0                                       1、飛行前請確認您的身心健康狀態。
# 1
# 2                                       2、起飛時請借助風場或較高的地勢。
# 3
# 4                              3、使用風之翼飛行時請注意風勢與風向，維持飛行平衡。
# ...                                                   ...
# 592047                     遠古寶玉造的，能守護一國的勁弓，以匯聚一線的翠光為幻造的弦。
# 592048                                               懸黎千鈞
# 592049                                  goto -39 229 9988
# 592050                                              驟起的魔花
# 592051  傳說中，追隨風之神的詩人踏遍了一千世界。歌集中記載了諸多奇景，飽含偉力。這些斷章有些丟失了，...
#
#                                                   text_DE  \
# 0       1. Vergewissere dich deiner geistigen und körp...
# 1
# 2       2. Starte von einem Windfeld oder hoch gelegen...
# 3
# 4       3. Achte bei der Nutzung eines Windgleiters au...
# ...                                                   ...
# 592047  Ein aus uralter Jade gefertigter Bogen zum Sch...
# 592048                             Urzeitlicher Jadebogen
# 592049                                  goto -39 229 9988
# 592050                          Aufstieg der Teufelsblume
# 592051  Der Legende zufolge besuchte der Dichter, der ...
#
#                                                   text_EN  \
# 0       1. Before gliding, make sure you are physicall...
# 1
# 2       2. Make use of a wind current or elevated terr...
# 3
# 4       3. Keep an eye on the wind conditions while gl...
# ...                                                   ...
# 592047  A strong bow that was made from ancient jade, ...
# 592048                              Primordial Jade Vista
# 592049                                  goto -39 229 9988
# 592050                            Rise of the Fell Flower
# 592051  Legend has it that the bard who walked with th...
#
#                                                   text_ES  \
# 0       1. Antes de volar, compruebe que está en buen ...
# 1
# 2       2. Despegue ayudándose de una corriente de vie...
# 3
# 4       3. Tenga en cuenta la velocidad y dirección de...
# ...                                                   ...
# 592047  Un gran arco hecho de un ámbar antiguo complet...
# 592048                           Vista de Jade Primordial
# 592049                                  goto -39 229 9988
# 592050                      El ascenso de la flor maldita
# 592051  La leyenda dice que el bardo que caminó con el...
#
#                                                   text_FR  \
# 0       1. Veuillez vous assurer que vous êtes physiqu...
# 1
# 2       2. Commencez par vous entraîner avec un champ ...
# 3
# 4       3. Faites attention à la force et la direction...
# ...                                                   ...
# 592047  Un arc puissant fait de jade antique qui peut ...
# 592048                             Vue de jade primordial
# 592049                                  goto -39 229 9988
# 592050                      L'ascension de la Gangrefleur
# 592051  La légende dit qu'un barde avait parcouru des ...
#
#                                                   text_ID  \
# 0       1. Sebelum terbang, pastikan kesehatan tubuh d...
# 1
# 2       2. Manfaatkan arus angin atau ketinggian yang ...
# 3
# 4       3. Perhatikanlah kondisi angin di setiap waktu...
# ...                                                   ...
# 592047  Sebuah busur kuat yang tubuhnya terbuat dari g...
# 592048                              Primordial Jade Vista
# 592049                                  goto -39 229 9988
# 592050                        Bangkitnya Bunga yang Jatuh
# 592051  Menurut legenda, penyair yang berjalan bersama...
#
#                                                   text_IT  \
# 0       1. Prima di usare un aliante, preparati fisica...
# 1
# 2       2. Per il decollo sfrutta le correnti d'aria o...
# 3
# 4       3. Mentre voli tieni d'occhio le condizioni de...
# ...                                                   ...
# 592047                                                NaN
# 592048                                                NaN
# 592049                                  goto -39 229 9988
# 592050                            L'ascesa del Demonfiore
# 592051                                                NaN
#
#                                                   text_JP  \
# 0                                   1、飛行前に心身の健康状態を確認すること。
# 1
# 2                              2、飛び立つ時は風域、または高い地形を利用すること。
# 3
# 4                    3、風の翼を使用する時は風力と風向きに注意して、バランスを維持すること。
# ...                                                   ...
# 592047                上古の宝玉で作られた、一国を守れる弓。一線に集まる光は幻造の弦になる。
# 592048                                             高価なオーブ
# 592049                                  goto -39 229 9988
# 592050                                             蔓延る魔の花
# 592051  伝説では、風の神を追随する詩人が千の世界を踏破したらしい。その歌集には様々な奇景が記載されて...
#
#                                                   text_KR  \
# 0                               1. 비행 전 심신의 건강 상태를 체크하세요.
# 1
# 2                     2. 날아오를 때는 윈드 필드를 이용하거나 높은 곳이 좋습니다.
# 3
# 4       3. 바람의 날개를 사용해 비행할 때에는 바람의 세기와 방향에 유의하여 평형을 유지...
# ...                                                   ...
# 592047  고대 보옥으로 만들어진 일국을 수호할 수 있는 강한 활. 푸른빛 줄기가 모여 활시위...
# 592048                                               현려천균
# 592049                                  goto -39 229 9988
# 592050                                          악마의 꽃의 습격
# 592051  전설에 의하면 바람의 신을 추종하던 시인이 전 세계를 모두 둘러보며 만들었다던 시가...
#
#                                                   text_PT  \
# 0       1. Antes de planar, certifique-se de que você ...
# 1
# 2       2. Faça uso de uma corrente de vento ou de um ...
# 3
# 4       3. Fique de olho nas condições do vento enquan...
# ...                                                   ...
# 592047  Um arco forte feito de jade antigo, com uma co...
# 592048                           Vista da Jade Primordial
# 592049                                  goto -39 229 9988
# 592050                           Ascensão da Flor Maldita
# 592051  Diz a lenda que o bardo que andou com o Deus d...
#
#                                                   text_RU  \
# 0       1. Перед полётом убедитесь в том, что вы готов...
# 1
# 2       2. Для взлёта используйте ветряные потоки или ...
# 3
# 4       3. Следите за воздушными потоками, чтобы не по...
# ...                                                   ...
# 592047  Лук, сделанный из древнего нефрита, с тетивой,...
# 592048                           Древняя Нефритовая Виста
# 592049                                  goto -39 229 9988
# 592050                                 Восстание Злоцвета
# 592051  Легенды гласят, что бард, который ходил с архо...
#
#                                                   text_TH  \
# 0       1. เตรียมตัวให้พร้อมทั้งสภาพร่างกายและจิตใจก่อ...
# 1
# 2            2. พุ่งตัวออกจากพื้นที่สูงชัน หรือกระแสลมแรง
# 3
# 4       3. ตรวจสอบกระแสลมในขณะที่ใช้เครื่องร่อนเวหาบิน...
# ...                                                   ...
# 592047  คันธนูที่แข็งแกร่งที่ทำจากหยกโบราณด้วยสายที่ทำ...
# 592048                              Primordial Jade Vista
# 592049                                  goto -39 229 9988
# 592050                            การลุกฮือของดอกไม้ปีศาจ
# 592051  ในตำนานเล่าว่านักกวีที่ติดตามเทพแห่งลม เดินทาง...
#
#                                                   text_TR  \
# 0       1. Uçuştan önce fiziksel ve zihinsel olarak ha...
# 1
# 2       2. Kalkış için rüzgar akımından ya da yüksek b...
# 3
# 4       3. Uçuş sırasında dengenizi koruyabilmek için ...
# ...                                                   ...
# 592047                                                NaN
# 592048                                                NaN
# 592049                                  goto -39 229 9988
# 592050                            Düşen Çiçeğin Yükselişi
# 592051                                                NaN
#
#                                                   text_VI
# 0       1. Trước khi bay hãy xác nhận trạng thái thể c...
# 1
# 2       2. Khi cất cánh hãy mượn sức gió hoặc nơi có đ...
# 3
# 4       3. Khi dùng Phong Chi Dực bay lên hãy chú ý sứ...
# ...                                                   ...
# 592047  Tạo ra từ bảo ngọc viễn cổ, có thể bảo vệ một ...
# 592048                                      Cung Huyền Lê
# 592049                                  goto -39 229 9988
# 592050                                      Hoa Quỷ Nở Rộ
# 592051  Trong truyền thuyết, nhà thơ đi theo Phong Thầ...
#
# [592052 rows x 17 columns]

# %%
# len(merged_all_df[merged_all_df['zh_text_md5'].isna()])

# %% [markdown]
# # 数据清洗

# %%
def clean_text(text):
    if pd.isna(text):  # 跳过空值
        return text
    # 去除 HTML 样式标签
    text = re.sub(r'<[^>]+>', '', text)
    # 去除其他可能的占位符或多余符号
    # text = re.sub(r'\[.*?\]', '', text)
    # text = re.sub(r'/\*.*?\*/', '', text)
    return text

for col in list(merged_all_df.columns[2:]):
    merged_all_df[col] = merged_all_df[col].apply(clean_text)

# %%
def calculate_md5(text):
    return hashlib.md5(text.encode('utf-8')).hexdigest() if pd.notna(text) else None

merged_all_df['zh_text_md5'] = merged_all_df['text_CHS'].apply(calculate_md5)

# %%
# 定义 is_low_quality 函数
def is_low_quality(row):
    # 中文语料为空：检查 zh_text_md5 是否为 NaN
    if pd.isna(row['zh_text_md5']):
        return True
    
    # 中英文语料为空：检查 text_CHS 和 text_EN 是否同时为 NaN
    if pd.isna(row.get('text_CHS')) and pd.isna(row.get('text_EN')):
        return True
    
    # 中文语料为非中文：检查 text_CHS 是否为空字符串或不包含中文字符
    if row.get('text_CHS') == '' or not contains_chinese(row.get('text_CHS', '')):
        return True
    
    return False

# 正则匹配检查字符串是否包含中文字符
def contains_chinese(text):
    chinese_pattern = re.compile(r'[\u4e00-\u9fff]')
    return chinese_pattern.search(text) is not None

merged_all_df['is_low_quality'] = merged_all_df.apply(is_low_quality, axis=1)

# 定义is_duplicate列
merged_all_df['is_duplicate'] = merged_all_df.duplicated(subset='zh_text_md5', keep='first')

# 定义duplicated_crossing_file列，由于目前不需要检查改行所以注释掉了
# cross_file_duplicates = merged_all_df.groupby(['file_name', 'zh_text_md5']).size().reset_index(name='文件内出现次数')
# cross_file_duplicates = cross_file_duplicates.groupby('zh_text_md5').size().reset_index(name='文件数')
# merged_all_df = merged_all_df.merge(cross_file_duplicates[['zh_text_md5', '文件数']], on='zh_text_md5', how='left')
# merged_all_df['duplicated_crossing_file'] = merged_all_df['文件数'] > 1
# merged_all_df.drop(columns=['文件数'], inplace=True)

# %%
merged_all_df[merged_all_df['is_low_quality']==True]
# Out:
#                file_name  line_number text_CHS  \
# 1       AmborLicense.txt            2
# 3       AmborLicense.txt            4
# 5       AmborLicense.txt            6
# 7       AmborLicense.txt            8
# 9       AmborLicense.txt           10
# ...                  ...          ...      ...
# 592047   TextMapCHS.json       567871      NaN
# 592048   TextMapCHS.json       567872      NaN
# 592049   TextMapCHS.json       567873      NaN
# 592050   TextMapCHS.json       567874      NaN
# 592051   TextMapCHS.json       567875      NaN
#
#                                                  text_CHT  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047                     遠古寶玉造的，能守護一國的勁弓，以匯聚一線的翠光為幻造的弦。
# 592048                                               懸黎千鈞
# 592049                                  goto -39 229 9988
# 592050                                              驟起的魔花
# 592051  傳說中，追隨風之神的詩人踏遍了一千世界。歌集中記載了諸多奇景，飽含偉力。這些斷章有些丟失了，...
#
#                                                   text_DE  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047  Ein aus uralter Jade gefertigter Bogen zum Sch...
# 592048                             Urzeitlicher Jadebogen
# 592049                                  goto -39 229 9988
# 592050                          Aufstieg der Teufelsblume
# 592051  Der Legende zufolge besuchte der Dichter, der ...
#
#                                                   text_EN  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047  A strong bow that was made from ancient jade, ...
# 592048                              Primordial Jade Vista
# 592049                                  goto -39 229 9988
# 592050                            Rise of the Fell Flower
# 592051  Legend has it that the bard who walked with th...
#
#                                                   text_ES  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047  Un gran arco hecho de un ámbar antiguo complet...
# 592048                           Vista de Jade Primordial
# 592049                                  goto -39 229 9988
# 592050                      El ascenso de la flor maldita
# 592051  La leyenda dice que el bardo que caminó con el...
#
#                                                   text_FR  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047  Un arc puissant fait de jade antique qui peut ...
# 592048                             Vue de jade primordial
# 592049                                  goto -39 229 9988
# 592050                      L'ascension de la Gangrefleur
# 592051  La légende dit qu'un barde avait parcouru des ...
#
#                                                   text_ID  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047  Sebuah busur kuat yang tubuhnya terbuat dari g...
# 592048                              Primordial Jade Vista
# 592049                                  goto -39 229 9988
# 592050                        Bangkitnya Bunga yang Jatuh
# 592051  Menurut legenda, penyair yang berjalan bersama...
#
#                         text_IT  \
# 1
# 3
# 5
# 7
# 9
# ...                         ...
# 592047                      NaN
# 592048                      NaN
# 592049        goto -39 229 9988
# 592050  L'ascesa del Demonfiore
# 592051                      NaN
#
#                                                   text_JP  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047                上古の宝玉で作られた、一国を守れる弓。一線に集まる光は幻造の弦になる。
# 592048                                             高価なオーブ
# 592049                                  goto -39 229 9988
# 592050                                             蔓延る魔の花
# 592051  伝説では、風の神を追随する詩人が千の世界を踏破したらしい。その歌集には様々な奇景が記載されて...
#
#                                                   text_KR  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047  고대 보옥으로 만들어진 일국을 수호할 수 있는 강한 활. 푸른빛 줄기가 모여 활시위...
# 592048                                               현려천균
# 592049                                  goto -39 229 9988
# 592050                                          악마의 꽃의 습격
# 592051  전설에 의하면 바람의 신을 추종하던 시인이 전 세계를 모두 둘러보며 만들었다던 시가...
#
#                                                   text_PT  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047  Um arco forte feito de jade antigo, com uma co...
# 592048                           Vista da Jade Primordial
# 592049                                  goto -39 229 9988
# 592050                           Ascensão da Flor Maldita
# 592051  Diz a lenda que o bardo que andou com o Deus d...
#
#                                                   text_RU  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047  Лук, сделанный из древнего нефрита, с тетивой,...
# 592048                           Древняя Нефритовая Виста
# 592049                                  goto -39 229 9988
# 592050                                 Восстание Злоцвета
# 592051  Легенды гласят, что бард, который ходил с архо...
#
#                                                   text_TH  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047  คันธนูที่แข็งแกร่งที่ทำจากหยกโบราณด้วยสายที่ทำ...
# 592048                              Primordial Jade Vista
# 592049                                  goto -39 229 9988
# 592050                            การลุกฮือของดอกไม้ปีศาจ
# 592051  ในตำนานเล่าว่านักกวีที่ติดตามเทพแห่งลม เดินทาง...
#
#                         text_TR  \
# 1
# 3
# 5
# 7
# 9
# ...                         ...
# 592047                      NaN
# 592048                      NaN
# 592049        goto -39 229 9988
# 592050  Düşen Çiçeğin Yükselişi
# 592051                      NaN
#
#                                                   text_VI  \
# 1
# 3
# 5
# 7
# 9
# ...                                                   ...
# 592047  Tạo ra từ bảo ngọc viễn cổ, có thể bảo vệ một ...
# 592048                                      Cung Huyền Lê
# 592049                                  goto -39 229 9988
# 592050                                      Hoa Quỷ Nở Rộ
# 592051  Trong truyền thuyết, nhà thơ đi theo Phong Thầ...
#
#                              zh_text_md5  is_low_quality  is_duplicate
# 1       d41d8cd98f00b204e9800998ecf8427e            True         False
# 3       d41d8cd98f00b204e9800998ecf8427e            True          True
# 5       d41d8cd98f00b204e9800998ecf8427e            True          True
# 7       d41d8cd98f00b204e9800998ecf8427e            True          True
# 9       d41d8cd98f00b204e9800998ecf8427e            True          True
# ...                                  ...             ...           ...
# 592047                              None            True          True
# 592048                              None            True          True
# 592049                              None            True          True
# 592050                              None            True          True
# 592051                              None            True          True
#
# [13831 rows x 20 columns]

# %% [markdown]
# # 数据导出

# %%
time = datetime.datetime.now().strftime('%Y%m%d')
# 去重段落数: 以 zh_text 为依据，“重复了的段落”的个数
duplicate_sum = len(merged_all_df[merged_all_df['is_duplicate'] == True])
low_quality_sum = len(merged_all_df[merged_all_df['is_low_quality'] == True])
# 段落数: 等于整份文件中jsonl的行数
paragraphs_sum = merged_all_df.shape[0]

output_list = []
file_name_prefix = 'Genshin_AnimeGameData' #若更换输出文件名，请记得修改
# 由于Datacheck文件限制512MB文件输入,因此设置输出文件大小为510MB
max_file_size = 510 * 1024 * 1024 
current_file_index = 1
current_file_size = 0
current_output_path = os.path.join(root_directory, f"{file_name_prefix}_{current_file_index}.jsonl")

# 初始化
current_file = open(current_output_path, 'w', encoding='utf-8')

for idx, row in merged_all_df.iterrows():
    # 储存额外的小语种，可添加至扩展字段中
    other_texts = {
        'tr': str(row['text_TR'])
    }
    key = str(row['file_name']) + '_' + str(row['line_number'])

    entry = {
        "文件名": f"{file_name_prefix}_{current_file_index}.jsonl",
        "是否待查文件": False,
        "是否重复文件": False,
        "段落数": paragraphs_sum,
        "去重段落数": duplicate_sum,
        "低质量段落数": low_quality_sum,
        "行号": int(idx + 1),  # 段落下标，是一个取值范围在 [1, 段落数] 之间的整数
        "是否重复": bool(row['is_duplicate']),
        "是否跨文件重复": False,
        "it_text": str(row['text_IT']),
        "zh_text": str(row['text_CHS']),
        "en_text": str(row['text_EN']),
        "ar_text": "",
        "nl_text": "",
        "de_text": str(row['text_DE']),
        "eo_text": "",
        "fr_text": str(row['text_FR']),
        "he_text": "",
        "ja_text": str(row['text_JP']),
        "pt_text": str(row['text_PT']),
        "ru_text": str(row['text_RU']),
        "es_text": str(row['text_ES']),
        "sv_text": "",
        "ko_text": str(row['text_KR']),
        "th_text": str(row['text_TH']),
        "id_text": str(row['text_ID']),
        "cht_text": str(row['text_CHT']),
        "vi_text": str(row['text_VI']),
        "扩展字段": json.dumps({"k": key, "other_texts": other_texts}, ensure_ascii=False),
        "时间": time,
        "zh_text_md5": str(row['zh_text_md5'])
    }

    # 输出部分
    entry_json = json.dumps(entry, ensure_ascii=False) + '\n'
    entry_size = len(entry_json.encode('utf-8'))

    # 检查是否超出文件大小限制
    if current_file_size + entry_size > max_file_size:
        current_file.close()

        current_file_index += 1
        current_file_size = 0
        current_output_path = os.path.join(root_directory, f"{file_name_prefix}_{current_file_index}.jsonl")
        current_file = open(current_output_path, 'w', encoding='utf-8')

    current_file.write(entry_json)
    current_file_size += entry_size

current_file.close()

print('数据输出完成')
# Out:
# 数据输出完成
